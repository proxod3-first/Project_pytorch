# %% [markdown]
# <a href="https://colab.research.google.com/github/proxod3-first/Project_pytorch/blob/master/__PyTorch_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PyTorch project

# %%
# !git clone https://github.com/proxod3-first/Project_pytorch
# Out:
# Cloning into 'Project_pytorch'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 0), reused 8 (delta 0), pack-reused 0
# Receiving objects: 100% (11/11), done.

# %%
# %matplotlib inline

# %% [markdown]
# ##load_data.py

# %%
# %run Project_pytorch/load_data.py
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:10<00:00, 16256187.47it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# plane horse truck ship

# %% [markdown]
# ##nn_model.py

# %%
# %run Project_pytorch/nn_model.py
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# cat   frog  cat   cat

# %% [markdown]
# ##train.py

# %%
# %run Project_pytorch/train.py
# Out:
# [1,  2000] loss: 2.213
# [1,  4000] loss: 1.906
# [1,  6000] loss: 1.720
# [1,  8000] loss: 1.624
# [1, 10000] loss: 1.534
# [1, 12000] loss: 1.489
# [2,  2000] loss: 1.394
# [2,  4000] loss: 1.387
# [2,  6000] loss: 1.362
# [2,  8000] loss: 1.345
# [2, 10000] loss: 1.304
# [2, 12000] loss: 1.312
# Finished Training
# GroundTruth:  cat   ship  ship  plane
# Predicted:  cat   car   ship  ship
# Accuracy of the network on the 10000 test images: 51 %
# Accuracy for class: plane is 45.4 %
# Accuracy for class: car   is 64.7 %
# Accuracy for class: bird  is 63.2 %
# Accuracy for class: cat   is 37.8 %
# Accuracy for class: deer  is 18.9 %
# Accuracy for class: dog   is 41.6 %
# Accuracy for class: frog  is 71.1 %
# Accuracy for class: horse is 47.3 %
# Accuracy for class: ship  is 73.3 %
# Accuracy for class: truck is 47.9 %
# cpu
